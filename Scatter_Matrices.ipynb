# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
matrix = np.random.randn(1000,4)

# %%
matrix
# Out:
# array([[-0.43102296,  0.93019   ,  0.28733848,  1.48798272],
#        [ 0.5975581 ,  1.84351155, -0.19303159,  0.92892781],
#        [ 2.04875645,  0.22777601, -0.09437161,  0.64299943],
#        ...,
#        [-1.13408184,  0.48024298,  0.21576312,  0.50278459],
#        [-0.01552832,  0.67190494,  0.83854644,  0.82033122],
#        [ 0.27103603, -0.93887067,  0.39243893, -1.99918602]])

# %%
df = pd.DataFrame(matrix)

# %%
pd.plotting.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<AxesSubplot:xlabel='0', ylabel='0'>,
#         <AxesSubplot:xlabel='1', ylabel='0'>,
#         <AxesSubplot:xlabel='2', ylabel='0'>,
#         <AxesSubplot:xlabel='3', ylabel='0'>],
#        [<AxesSubplot:xlabel='0', ylabel='1'>,
#         <AxesSubplot:xlabel='1', ylabel='1'>,
#         <AxesSubplot:xlabel='2', ylabel='1'>,
#         <AxesSubplot:xlabel='3', ylabel='1'>],
#        [<AxesSubplot:xlabel='0', ylabel='2'>,
#         <AxesSubplot:xlabel='1', ylabel='2'>,
#         <AxesSubplot:xlabel='2', ylabel='2'>,
#         <AxesSubplot:xlabel='3', ylabel='2'>],
#        [<AxesSubplot:xlabel='0', ylabel='3'>,
#         <AxesSubplot:xlabel='1', ylabel='3'>,
#         <AxesSubplot:xlabel='2', ylabel='3'>,
#         <AxesSubplot:xlabel='3', ylabel='3'>]], dtype=object)

# %%
plt.scatter(matrix[:, 0], matrix[:, 1])

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
cluster = KMeans(n_clusters=1, random_state=0)
model = cluster.fit(matrix)

# %%
plt.scatter(matrix[:, 0], matrix[:, 1])
plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1])

# %%
print(cluster.cluster_centers_)
# Out:
# [[ 0.03977543 -0.0068603   0.01067791 -0.00545095]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
landtemps = pd.read_csv('C:/users/memdp/Python_Playground/text_files/landtemps2019avgs.txt')

# %%
landtemps
# Out:
#         locationid              station countryid  \
# 0      AE000041196   SHARJAH_INTER_AIRP        AE
# 1      AEM00041194           DUBAI_INTL        AE
# 2      AEM00041217       ABU_DHABI_INTL        AE
# 3      AEM00041218          AL_AIN_INTL        AE
# 4      AFM00040938                HERAT        AF
# ...            ...                  ...       ...
# 12090  WFM00091754  FUTUNA_ISL_MAOPOOPO        WF
# 12091  WIM00060096    VILLA_CISNEROSMIL        WI
# 12092  WQW00041606          WAKE_ISLAND        WQ
# 12093  ZA000067743          LIVINGSTONE        ZA
# 12094  ZI000067775       HARARE_KUTSAGA        ZI
#
#                            country   latabs  elevation    avgtemp
# 0             United Arab Emirates  25.3330       34.0  28.251667
# 1             United Arab Emirates  25.2550       10.4  29.585833
# 2             United Arab Emirates  24.4330       26.8  29.400000
# 3             United Arab Emirates  24.2620      264.9  29.061667
# ...

# %%
plt.figure(figsize=(15,15))
plt.scatter(x='latabs', y='avgtemp', data=landtemps)
plt.xlabel('Latitude (N or S)')
plt.ylabel('Average Temperature (Celsius)')
plt.yticks(np.arange(-60, 40, step=20))
plt.title('Latitude and Average Temperature in 2019')
plt.show()

# %%
pd.plotting.scatter_matrix(landtemps)
# Out:
# array([[<AxesSubplot:xlabel='latabs', ylabel='latabs'>,
#         <AxesSubplot:xlabel='elevation', ylabel='latabs'>,
#         <AxesSubplot:xlabel='avgtemp', ylabel='latabs'>],
#        [<AxesSubplot:xlabel='latabs', ylabel='elevation'>,
#         <AxesSubplot:xlabel='elevation', ylabel='elevation'>,
#         <AxesSubplot:xlabel='avgtemp', ylabel='elevation'>],
#        [<AxesSubplot:xlabel='latabs', ylabel='avgtemp'>,
#         <AxesSubplot:xlabel='elevation', ylabel='avgtemp'>,
#         <AxesSubplot:xlabel='avgtemp', ylabel='avgtemp'>]], dtype=object)

# %%
low, high = landtemps.loc[landtemps.elevation<=1000], landtemps.loc[landtemps.elevation>1000]
plt.figure(figsize=(15,15))
plt.scatter(x='latabs', y='avgtemp', c='blue',
            data=low)
plt.scatter(x='latabs', y='avgtemp', c='red',
            data=high)
